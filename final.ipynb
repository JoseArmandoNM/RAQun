# %% [markdown]
# # IMPORTS E INITS

# %%
import numpy as np
import pandas as pd
from raqun.utils.graph import inMat, matGen, mmng

X_r = '/home/elma/Documentos/RAQun/escalados.csv'
X = np.loadtxt(
    X_r,
    delimiter = ",", 
    skiprows = 1
)
X = X[:, :-1]

simMatrix = matGen(X)
np.savetxt('simMatrix.csv', simMatrix, delimiter = ',')

'''
matriz de similitud
mmng
matriz de incidencia
'''
# Out:
# '\nmatriz de similitud\nmmng\nmatriz de incidencia\n'
